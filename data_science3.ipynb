# %% [markdown]
# <a href="https://colab.research.google.com/github/FARZEEN2007/data_science/blob/main/data_science3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[20,40,60,80,100]
s=pd.Series(data,index=['A','B','C','D','E'])
print(s)
# Out:
# A     20
# B     40
# C     60
# D     80
# E    100
# dtype: int64

# %%
data={"NAME":"farzeen","age":19}
s=pd.Series(data)
print(s)
# Out:
# NAME    farzeen
# age          19
# dtype: object

# %%
data1=[10,30,50,70]
s=pd.Series(data1)
print(s.loc[1])
# Out:
# 30

# %%
data=[10,30,50,70]
s=pd.Series(data,index=['A','B','C','D'])
print(s.iloc[3])
# Out:
# 70

# %%
data2=[10,20,30,40]
s=pd.Series(data2,index=['A','B','C','D'])
print(s.loc["A":"B"])
print(s.iloc[:2])
print(s.loc[s>10])
# Out:
# A    10
# B    20
# dtype: int64
# A    10
# B    20
# dtype: int64
# B    20
# C    30
# D    40
# dtype: int64

# %%
data3=[5,10,15,20]
s=pd.Series(data3)
print(s)
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# dtype: int64

# %%
sales = pd.Series([900,2000,3000,4000],index=["Monday","Tuesday","Wednesday","Thursday"])
print(sales)
print(sales.max())
print(sales.sum())
print(sales[sales<1000])
# Out:
# Monday        900
# Tuesday      2000
# Wednesday    3000
# Thursday     4000
# dtype: int64
# 4000
# 9900
# Monday    900
# dtype: int64

# %%
data = [20,20,30,50,30,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
# Out:
# 0    20
# 1    20
# 2    30
# 3    50
# 4    30
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]

# %%
data = [20,20,30,50,30,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
print(ar.nunique())                 #to get the count
print(ar.value_counts())            #counts of repeated numbers
# Out:
# 0    20
# 1    20
# 2    30
# 3    50
# 4    30
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]
# 5
# 20    2
# 30    2
# 60    2
# 50    1
# 80    1
# Name: count, dtype: int64

# %%
data = [20,20,30,None,50,30,60,60,80,None]
ar=pd.Series(data)
print(ar)
print(ar.isna())
# Out:
# 0    20.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    50.0
# 5    30.0
# 6    60.0
# 7    60.0
# 8    80.0
# 9     NaN
# dtype: float64
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
data = [20,20,30,None,50,30,60,60,80,None]
ar=pd.Series(data)
print(ar)
print(ar.notna())
# Out:
# 0    20.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    50.0
# 5    30.0
# 6    60.0
# 7    60.0
# 8    80.0
# 9     NaN
# dtype: float64
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# dtype: bool

# %%
data = [20,20,30,None,50,30,60,60,80,None]
ar=pd.Series(data)
print(ar)
print(ar.dropna())       #USE FOR REMOVING NULL
# Out:
# 0    20.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    50.0
# 5    30.0
# 6    60.0
# 7    60.0
# 8    80.0
# 9     NaN
# dtype: float64
# 0    20.0
# 1    20.0
# 2    30.0
# 4    50.0
# 5    30.0
# 6    60.0
# 7    60.0
# 8    80.0
# dtype: float64

# %%
import pandas as pd
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark)
# Out:
# anu       78.0
# rahul     45.0
# meera     89.0
# arun      67.0
# neha      92.0
# vishnu    45.0
# diya      56.0
# akhil     78.0
# riya       NaN
# kiran     34.0
# dtype: float64

# %% [markdown]
# 2

# %%
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark.size)
print(mark.sum())
# Out:
# 10
# 584.0

# %% [markdown]
# 3

# %%
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark.mean())
print(mark.max())
print(mark.min())
# Out:
# 64.88888888888889
# 92.0
# 34.0

# %% [markdown]
# 4

# %% [markdown]
# 5

# %%
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark.isna().sum())
# Out:
# 1

# %% [markdown]
# 6

# %%
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark.fillna(0))
# Out:
# anu       78.0
# rahul     45.0
# meera     89.0
# arun      67.0
# neha      92.0
# vishnu    45.0
# diya      56.0
# akhil     78.0
# riya       0.0
# kiran     34.0
# dtype: float64

# %% [markdown]
# 7

# %%
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark.unique())
print(mark.nunique())
# Out:
# [78. 45. 89. 67. 92. 56. nan 34.]
# 7

# %% [markdown]
# 8

# %%
mark = pd.Series([78,45,89,67,92,45,56,78,None,34],index=["anu","rahul","meera","arun","neha","vishnu","diya","akhil","riya","kiran"])
print(mark[mark > 70])
# Out:
# anu      78.0
# meera    89.0
# neha     92.0
# akhil    78.0
# dtype: float64

# %% [markdown]
# 9

# %% [markdown]
# DATA FRAME

# %%
import numpy as np
data = {
    "Name": ["Alice","Bob","Charlie","David","Emma"],
    "Age": [20,21,19,22,20],
    "Marks": [85,72,np.nan,90,65],
    "Attendance": [95,80,75,np.nan,88],
    "City": ["Kochi","Delhi","Mumbai","Kochi","Chennai"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks  Attendance     City
# 0    Alice   20   85.0        95.0    Kochi
# 1      Bob   21   72.0        80.0    Delhi
# 2  Charlie   19    NaN        75.0   Mumbai
# 3    David   22   90.0         NaN    Kochi
# 4     Emma   20   65.0        88.0  Chennai

# %%
data = {
    "Name": ["Alice","Bob","Charlie","David","Emma"],
    "Age": [20,21,19,22,20],
    "Marks": [85,72,np.nan,90,65],
    "Attendance": [95,80,75,np.nan,88],
    "City": ["Kochi","Delhi","Mumbai","Kochi","Chennai"]
}
df = pd.DataFrame(data)
print(df.head(3))           #for first 3 rows
# Out:
#       Name  Age  Marks  Attendance    City
# 0    Alice   20   85.0        95.0   Kochi
# 1      Bob   21   72.0        80.0   Delhi
# 2  Charlie   19    NaN        75.0  Mumbai

# %%
print(df.tail(2))           #for last 2 rows
# Out:
#     Name  Age  Marks  Attendance     City
# 3  David   22   90.0         NaN    Kochi
# 4   Emma   20   65.0        88.0  Chennai

# %%
data = {
    "Name": ["Alice","Bob","Charlie","David","Emma"],
    "Age": [20,21,19,22,20],
    "Marks": [85,72,np.nan,90,65],
    "Attendance": [95,80,75,np.nan,88],
    "City": ["Kochi","Delhi","Mumbai","Kochi","Chennai"]
}
df = pd.DataFrame(data)
print(df.shape)
# Out:
# (5, 5)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks', 'Attendance', 'City'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Name           object
# Age             int64
# Marks         float64
# Attendance    float64
# City           object
# dtype: object

# %%
print(df["Marks"])
# Out:
# 0    85.0
# 1    72.0
# 2     NaN
# 3    90.0
# 4    65.0
# Name: Marks, dtype: float64

# %%
print(df[["Name","Marks"]])
# Out:
#       Name  Marks
# 0    Alice   85.0
# 1      Bob   72.0
# 2  Charlie    NaN
# 3    David   90.0
# 4     Emma   65.0

# %%
print(df.iloc[0:3])
# Out:
#       Name  Age  Marks  Attendance    City
# 0    Alice   20   85.0        95.0   Kochi
# 1      Bob   21   72.0        80.0   Delhi
# 2  Charlie   19    NaN        75.0  Mumbai

# %%
print(df.loc[1:3,["Name","Marks"]])
# Out:
#       Name  Marks
# 1      Bob   72.0
# 2  Charlie    NaN
# 3    David   90.0

# %%
print(df[df["Marks"] > 75])
# Out:
#     Name  Age  Marks  Attendance   City
# 0  Alice   20   85.0        95.0  Kochi
# 3  David   22   90.0         NaN  Kochi

# %%
print(df[df["City"] == "Kochi"])
# Out:
#     Name  Age  Marks  Attendance   City
# 0  Alice   20   85.0        95.0  Kochi
# 3  David   22   90.0         NaN  Kochi

# %%
print(
    df[
        (df["Marks"]>70) &
        (df["Attendance"]>80)
        ]
    )
# Out:
#     Name  Age  Marks  Attendance   City
# 0  Alice   20   85.0        95.0  Kochi

# %%
print(df["Marks"]+5)
# Out:
# 0    90.0
# 1    77.0
# 2     NaN
# 3    95.0
# 4    70.0
# Name: Marks, dtype: float64

# %%
print(df["Marks"]*2)
# Out:
# 0    170.0
# 1    144.0
# 2      NaN
# 3    180.0
# 4    130.0
# Name: Marks, dtype: float64

# %%
print(df["Marks"].mean())
# Out:
# 78.0

# %%
print(df["Marks"].max())
# Out:
# 90.0

# %%
print(df["Marks"].min())
# Out:
# 65.0

# %%
print(df["Marks"].sum())
# Out:
# 312.0

# %%
print(df.sort_values("Marks"))
# Out:
#       Name  Age  Marks  Attendance     City
# 4     Emma   20   65.0        88.0  Chennai
# 1      Bob   21   72.0        80.0    Delhi
# 0    Alice   20   85.0        95.0    Kochi
# 3    David   22   90.0         NaN    Kochi
# 2  Charlie   19    NaN        75.0   Mumbai

# %%
print(df.sort_values("Marks",ascending=False))
# Out:
#       Name  Age  Marks  Attendance     City
# 3    David   22   90.0         NaN    Kochi
# 0    Alice   20   85.0        95.0    Kochi
# 1      Bob   21   72.0        80.0    Delhi
# 4     Emma   20   65.0        88.0  Chennai
# 2  Charlie   19    NaN        75.0   Mumbai

# %%
df_renamed = df.rename(
    columns={
        "Marks":"Score",
        "Attendance":"Attendance_Percentage"
    }
)

print(df_renamed)
# Out:
#       Name  Age  Score  Attendance_Percentage     City
# 0    Alice   20   85.0                   95.0    Kochi
# 1      Bob   21   72.0                   80.0    Delhi
# 2  Charlie   19    NaN                   75.0   Mumbai
# 3    David   22   90.0                    NaN    Kochi
# 4     Emma   20   65.0                   88.0  Chennai

# %%
print(df.isna())
# Out:
#     Name    Age  Marks  Attendance   City
# 0  False  False  False       False  False
# 1  False  False  False       False  False
# 2  False  False   True       False  False
# 3  False  False  False        True  False
# 4  False  False  False       False  False

# %%
print(df.isna().sum())
# Out:
# Name          0
# Age           0
# Marks         1
# Attendance    1
# City          0
# dtype: int64

# %%
print(df.dropna())
# Out:
#     Name  Age  Marks  Attendance     City
# 0  Alice   20   85.0        95.0    Kochi
# 1    Bob   21   72.0        80.0    Delhi
# 4   Emma   20   65.0        88.0  Chennai

# %%
df_forward = df.copy()                      # for replacing null value (take the value from above)
df_forward = df_forward.ffill()
print(df_forward)
# Out:
#       Name  Age  Marks  Attendance     City
# 0    Alice   20   85.0        95.0    Kochi
# 1      Bob   21   72.0        80.0    Delhi
# 2  Charlie   19   72.0        75.0   Mumbai
# 3    David   22   90.0        75.0    Kochi
# 4     Emma   20   65.0        88.0  Chennai

# %%
df_backward = df.copy()                    # for replacing null value (take the value from below)
df_backward = df_backward.bfill()
print(df_backward)
# Out:
#       Name  Age  Marks  Attendance     City
# 0    Alice   20   85.0        95.0    Kochi
# 1      Bob   21   72.0        80.0    Delhi
# 2  Charlie   19   90.0        75.0   Mumbai
# 3    David   22   90.0        88.0    Kochi
# 4     Emma   20   65.0        88.0  Chennai
